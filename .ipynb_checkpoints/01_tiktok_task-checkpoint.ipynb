# %% [markdown]
# # TikTok data and LLM coding

# %% [markdown]
# ### Setup
#
# Run the following cells to set up this notebook

# %%
import ast
from IPython.display import display, clear_output
import json
from ipywidgets import widgets, VBox, HBox, Button, Label, Output
import krippendorff
import pandas as pd
import pyktok as pyk
import random
from openai import OpenAI
import seaborn as sns
import matplotlib.pyplot as plt

from dotenv import load_dotenv

_ = load_dotenv()

# %%
client = OpenAI()

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Exploring Public Opinion in TikTok Comments

# %% [markdown]
# This week we will be exploring TikTok's role in shaping public opinion. Social media has become a popular site of discourse, and platforms like TikTok have been credited for shaping popular culture, politics, and everyday interactions. TikTok comment sections are a site where public opinion is debated and negotiated. At the same time, platform-level decisions alter what comments are most visible on comment pages.

# %% [markdown]
# ## Choosing a Debate

# %% [markdown]
# Create a group of 2 (where at least one person in the group has a TikTok account) and find a video related to popular culture that has discusses two clearly defined positions as a part of a greater debate. This video should also have at least 1k comments. Copy the url of the video and paste it below.

# %%
# Replace with your video URL
video_url = "https://www.tiktok.com/@isitherightword/video/7569133665964297502?q=kayla%20nicole%20taylor%20swift&t=1762543436194"

# %% [markdown]
# ## Scrape Comments!

# %%
async def get_comments():
    pyk.save_tiktok_comments(video_url,
                         comment_count=1000,
                         save_comments=True,
                         return_comments=False,)

await get_comments()
# Out:
# /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/pyktok/pyktok.py:25: SyntaxWarning: invalid escape sequence '\.'
#   url_regex = '(?<=\.com/)(.+?)(?=\?|$)'
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[24], line 7
#       1 async def get_comments():
#       2     pyk.save_tiktok_comments(video_url,
#       3                          comment_count=1000,
#       4                          save_comments=True,
#       5                          return_comments=False,)
# ----> 7 await get_comments()
#
# Cell In[24], line 2, in get_comments()
#       1 async def get_comments():
# ----> 2     pyk.save_tiktok_comments(video_url,
#       3                          comment_count=1000,
#       4                          save_comments=True,
#       5                          return_comments=False,)
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/pyktok/pyktok.py:432, in save_tiktok_comments(video_url, filename, comment_count, headless, save_comments, return_comments)
#     425 def save_tiktok_comments(video_url,
#     426                          filename='',
#     427                          comment_count=30,
#     428                          headless=True,
#     429                          save_comments=True,
#     430                          return_comments=True):
#     431     video_id = int(re.findall(video_id_regex,video_url)[0])
# --> 432     comment_results = asyncio.run(get_comments(video_id,comment_count,headless))
#     433     if save_comments:
#     434         if filename == '':
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /usr/lib/python3.12/asyncio/futures.py:202, in Future.result(self)
#     200 self.__log_traceback = False
#     201 if self._exception is not None:
# --> 202     raise self._exception.with_traceback(self._exception_tb)
#     203 return self._result
#
# File /usr/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/pyktok/pyktok.py:415, in get_comments(video_id, comment_count, headless)
#     413 comment_list = []
#     414 async with TikTokApi() as api:
# --> 415     await api.create_sessions(headless=headless,
#     416                               ms_tokens=[ms_token],
#     417                               num_sessions=1,
#     418                               sleep_after=3,
#     419                               context_options=context_dict)
#     420     video = api.video(id=video_id)
#     421     async for comment in video.comments(count=comment_count):
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/TikTokApi/tiktok.py:521, in TikTokApi.create_sessions(self, num_sessions, headless, ms_tokens, proxies, proxy_provider, proxy_algorithm, sleep_after, starting_url, context_options, override_browser_args, cookies, suppress_resource_load_types, browser, executable_path, page_factory, browser_context_factory, timeout, enable_session_recovery, allow_partial_sessions, min_sessions)
#     519         override_browser_args = ["--headless=new"]
#     520         headless = False  # managed by the arg
# --> 521     self.browser = await self.playwright.chromium.launch(
#     522         headless=headless,
#     523         args=override_browser_args,
#     524         proxy=random_choice(proxies),
#     525         executable_path=executable_path,
#     526     )
#     527 elif browser == "firefox":
#     528     self.browser = await self.playwright.firefox.launch(
#     529         headless=headless,
#     530         args=override_browser_args,
#     531         proxy=random_choice(proxies),
#     532         executable_path=executable_path,
#     533     )
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/playwright/async_api/_generated.py:14465, in BrowserType.launch(self, executable_path, channel, args, ignore_default_args, handle_sigint, handle_sigterm, handle_sighup, timeout, env, headless, devtools, proxy, downloads_path, slow_mo, traces_dir, chromium_sandbox, firefox_user_prefs)
#   14344 async def launch(
#   14345     self,
#   14346     *,
#    (...)
#   14367     ] = None,
#   14368 ) -> "Browser":
#   14369     """BrowserType.launch
#   14370
#   14371     Returns the browser instance.
#    (...)
#   14461     Browser
#   14462     """
#   14464     return mapping.from_impl(
# > 14465         await self._impl_obj.launch(
#   14466             executablePath=executable_path,
#   14467             channel=channel,
#   14468             args=mapping.to_impl(args),
#   14469             ignoreDefaultArgs=mapping.to_impl(ignore_default_args),
#   14470             handleSIGINT=handle_sigint,
#   14471             handleSIGTERM=handle_sigterm,
#   14472             handleSIGHUP=handle_sighup,
#   14473             timeout=timeout,
#   14474             env=mapping.to_impl(env),
#   14475             headless=headless,
#   14476             devtools=devtools,
#   14477             proxy=proxy,
#   14478             downloadsPath=downloads_path,
#   14479             slowMo=slow_mo,
#   14480             tracesDir=traces_dir,
#   14481             chromiumSandbox=chromium_sandbox,
#   14482             firefoxUserPrefs=mapping.to_impl(firefox_user_prefs),
#   14483         )
#   14484     )
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/playwright/_impl/_browser_type.py:98, in BrowserType.launch(self, executablePath, channel, args, ignoreDefaultArgs, handleSIGINT, handleSIGTERM, handleSIGHUP, timeout, env, headless, devtools, proxy, downloadsPath, slowMo, tracesDir, chromiumSandbox, firefoxUserPrefs)
#      93 params = locals_to_params(locals())
#      94 normalize_launch_params(params)
#      95 browser = cast(
#      96     Browser,
#      97     from_channel(
# ---> 98         await self._channel.send(
#      99             "launch", TimeoutSettings.launch_timeout, params
#     100         )
#     101     ),
#     102 )
#     103 browser._connect_to_browser_type(
#     104     self, str(tracesDir) if tracesDir is not None else None
#     105 )
#     106 return browser
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/playwright/_impl/_connection.py:69, in Channel.send(self, method, timeout_calculator, params, is_internal, title)
#      61 async def send(
#      62     self,
#      63     method: str,
#    (...)
#      67     title: str = None,
#      68 ) -> Any:
# ---> 69     return await self._connection.wrap_api_call(
#      70         lambda: self._inner_send(method, timeout_calculator, params, False),
#      71         is_internal,
#      72         title,
#      73     )
#
# File /opt/jupyterhub/share/jupyter/venv/python3-12_comm4190/lib/python3.12/site-packages/playwright/_impl/_connection.py:558, in Connection.wrap_api_call(self, cb, is_internal, title)
#     556     return await cb()
#     557 except Exception as error:
# --> 558     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
#     559 finally:
#     560     self._api_zone.set(None)
#
# Error: BrowserType.launch: Executable doesn't exist at /Commjhub/jupyterhub/home/emily8354/.cache/ms-playwright/chromium-1187/chrome-linux/chrome
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝

# %% [markdown]
# ## Define a Research Question
# What are you hoping to learn by studying comments on this video?

# %% [markdown]
# We want to gage public consensus over Taylor and Kayla through the comments.

# %% [markdown]
# ## Defining Concepts
# Quantitative content analysis is a popular method for translating non-numeric content into numeric, quantitative data. To do so, researchers create clearly defined and validated concepts. The first step in studying our TikTok debate is clearly defining how each position should be coded.

# %%
concept1 = "Code 1 if the comment explicitly supports Kayla Nicole or does not support Taylor Swift. Code 0 if it does not."

concept2 = "Code 1 if the comment explicitly supports Taylor Swift or does not support Kayla Nicole . Code 0 if it does not."

# %% [markdown]
# ## Let's Code!

# %%
# !!Replace with your filename!!
df = pd.read_csv('@isitherightword_video_7569133665964297502_comments.csv') 

sample_df = df.sample(n=100, random_state=42).reset_index(drop=True)
text_col = 'text'

for col in ['coder1_concept1', 'coder1_concept2', 'coder2_concept1', 'coder2_concept2']:
    sample_df[col] = None

main_out = Output()
coder1_out = Output()
coder2_out = Output()

def code_entries(coder_label, concept1_col, concept2_col, container_out, next_callback=None):
    index = 0
    text_label = Label(value=sample_df.loc[index, text_col])

    # !!Change the descriptions to your concepts!!
    concept1 = widgets.ToggleButtons(options=[0, 1], description='Pro Kayla:')
    concept2 = widgets.ToggleButtons(options=[0, 1], description='Pro Taylor')
    
    next_button = Button(description='Next →', button_style='success')
    progress = Label(value=f"{coder_label}: {index + 1}/{len(sample_df)}")

    def next_entry(_):
        nonlocal index
        sample_df.loc[index, concept1_col] = concept1.value
        sample_df.loc[index, concept2_col] = concept2.value

        index += 1
        if index < len(sample_df):
            text_label.value = sample_df.loc[index, text_col]
            concept1.value = None
            concept2.value = None
            progress.value = f"{coder_label}: {index + 1}/{len(sample_df)}"
        else:
            container_out.clear_output()
            with container_out:
                display(Label(value=f"{coder_label} has finished coding! ✅"))
                if next_callback:
                    next_callback()
                else:
                    with main_out:
                        print("✅ Both coders finished. Saving data...")
                        sample_df.to_csv('coded_data.csv', index=False)
                        print("💾 Coded data saved to coded_data.csv")

    next_button.on_click(next_entry)

    with container_out:
        container_out.clear_output()
        display(VBox([progress, text_label, concept1, concept2, next_button]))

# ---- Workflow ----

def start_coder2():
    print("\n=== Coder 2: Please start coding ===")
    code_entries("Coder 2", "coder2_concept1", "coder2_concept2", coder2_out)

print(f"Concept 1: {concept1}")
print(f"Concept 2: {concept2}\n")

print("=== Coder 1: Please start coding ===")
code_entries("Coder 1", "coder1_concept1", "coder1_concept2", coder1_out, next_callback=start_coder2)

display(coder1_out, coder2_out, main_out)
# Out:
# Concept 1: Code 1 if the comment explicitly supports Kayla Nicole or does not support Taylor Swift. Code 0 if it does not.
# Concept 2: Code 1 if the comment explicitly supports Taylor Swift or does not support Kayla Nicole . Code 0 if it does not.
#
# === Coder 1: Please start coding ===
# Output()
# Output()
# Output()

# %% [markdown]
# ## Assess Interrater Reliability

# %%
df = pd.read_csv("coded_data.csv")

def krippendorff_alpha_for_concept(df, concept_name):
    data = [
        df[f'coder1_{concept_name}'].tolist(),
        df[f'coder2_{concept_name}'].tolist()
    ]
    return krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')

alpha_concept1 = krippendorff_alpha_for_concept(df, "concept1")
alpha_concept2 = krippendorff_alpha_for_concept(df, "concept2")

print("Krippendorff’s Alpha Scores:")
print(f"• Concept 1: {alpha_concept1:.3f}")
print(f"• Concept 2: {alpha_concept2:.3f}")
# Out:
# Krippendorff’s Alpha Scores:
# • Concept 1: 0.227
# • Concept 2: 0.363

# %% [markdown]
# ## Evaluate the interrater reliability and iterate!

# %% [markdown]
# ![](krippendorff.png)

# %% [markdown]
# Describe your interrater reliability. If you scored high, great! How did your concept descriptions help you code effectively? If you scored poorly, what might you have done better?
#
# **Regardless of your score, discuss potential edge cases and improve your concept descriptions**

# %% [markdown]
# ## Hire a LLM coder!
# Write a prompt for an LLM to code the same 100 comments and calculate intercoder reliability. Be sure to tell the LLM their role!

# %%
LLM_prompt = '''
        You are a research assistant coding TikTok comments about Kayla Nicole and Taylor Swift.
        
        CONTEXT: 
        - Kayla Nicole (Black woman) is Travis Kelce's ex-girlfriend
        - Taylor Swift is currently dating Travis Kelce
        - The TikTok video discusses Kayla Nicole's Halloween costume response to Taylor Swift
        - There is controversy around whether Taylor Swift's song lyrics targeted Kayla Nicole
        
        Concept 1 - Pro-Kayla Nicole / Anti-Taylor Swift
        Code 1 if the comment shows ANY of the following:
        
        DIRECT SUPPORT for Kayla:
          - Praises Kayla specifically: "she looks incredible", "GOD Kayla looks INCREDIBLE"
          - Supports her actions: "loved it", "excellent clapback"
          
        CRITICISM of Taylor Swift:
          - Direct criticism: "disappointed in her", "billionaire bully", "cringe", "cornball"
          - Implicit criticism: "the fall Taylor needs", "no ethical billionaires"
          - Criticism of her songs/lyrics: "lyrics felt very yucky"
        
        DO NOT code as 1:
          - Generic positive reactions: "Well said!", "❤", "💯"
          - Comments just about liking the video creator
          - Pure emojis without context
        
        Concept 2 - Pro-Taylor Swift / Anti-Kayla Nicole  
        Code 1 if the comment shows ANY of the following:
        
        CRITICISM of Kayla Nicole:
          - "desperate ex vibes", "calculated to choose tiny bikinis"
          
        DEFENSE of Taylor Swift:
          - "people saying that's a reach are delusional"
          - Defending her lyrics or actions
        
        DISMISSING concerns about Taylor:
          - "why is this a race thing? they're both beautiful women"
          
        CONFLICTED SWIFTIES:
          - Self-identified Taylor fans even if somewhat critical
        
        CRITICAL RULES:
        1. A comment CAN be coded 1 for BOTH concepts if it shows mixed opinions
        2. Brief reactions = Code 0 UNLESS they clearly reference Kayla/Taylor specifically
        3. When uncertain, ask: "Is this comment taking a side?" If NO → Code 0,0
'''

# %% [markdown]
# ## Code with your LLM coder!
# For the human coding, agree on a code with your partner for each of the concept

# %%
text_col = "text"
df = pd.read_csv('@isitherightword_video_7569133665964297502_comments.csv') 
sample_df = df.sample(n=100, random_state = 11).reset_index(drop=True)
sample_df["human_concept1"] = None
sample_df["human_concept2"] = None

def code_entries():
    index = 0
    out = Output()

    text_label = widgets.Textarea(value=sample_df.loc[index, text_col], layout=widgets.Layout(width='600px', height='120px'))
    concept1 = widgets.ToggleButtons(options=[0, 1], description="Concept 1:")
    concept2 = widgets.ToggleButtons(options=[0, 1], description="Concept 2:")
    next_button = Button(description="Next →", button_style="success")
    progress = Label(value=f"Human Coding: {index + 1}/{len(sample_df)}")

    def next_entry(_):
        nonlocal index
        sample_df.loc[index, "human_concept1"] = concept1.value
        sample_df.loc[index, "human_concept2"] = concept2.value

        index += 1
        if index < len(sample_df):
            text_label.value = sample_df.loc[index, text_col]
            concept1.value = None
            concept2.value = None
            progress.value = f"Human Coding: {index + 1}/{len(sample_df)}"
        else:
            clear_output()
            display(Label(value="✅ Human coding complete! Now AI will code the same sample."))
            out.clear_output()

    next_button.on_click(next_entry)
    display(VBox([progress, text_label, concept1, concept2, next_button, out]))

code_entries()
# Out:
# VBox(children=(Label(value='Human Coding: 1/100'), Textarea(value='Kayla kind of looks like Ayra Starr', layou…

# %%
sample_df.drop_duplicates(subset='cid').to_csv('human_coded_data3.csv')

# %%
print(len(sample_df))
# Out:
# 102

# %%
sample_df = sample_df.head(100)

# %%
batch_size = 10

def ai_code_batch(text_list):
    texts_formatted = "\n".join([f"{i+1}. {t}" for i, t in enumerate(text_list)])
    
    prompt = f"""
        {LLM_prompt}
        
        You will receive {len(text_list)} texts.
        
        Return ONLY valid JSON — a list of {len(text_list)} dictionaries like this:
        
        [
          {{"concept1": 1, "concept2": 0}},
          ...
        ]
        
        No explanations, no comments, no extra text — only the JSON array.
        
        Texts:
        {texts_formatted}
        """

    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    try:
        output_text = response.choices[0].message.content.strip()
        batch_json = json.loads(output_text)
        return batch_json  
    except Exception as e:
        try:
            print("Trying to parse")
            s = string.replace("```", "").replace("json", "").replace("\n", "").strip()
            lst = json.loads(s)
            print("✅ Parsed successfully.")
            return lst
        except Exception as e:
            print("⚠️ Parsing error:", e)

            return [{"concept1": None, "concept2": None} for _ in text_list]

# %%
sample_ai_concept1, sample_ai_concept2 = [], []

for start in range(0, len(sample_df), batch_size):
    print(f"Beginning coding round {batch_size/10}")
    end = start + batch_size
    sample_batch_texts = sample_df[text_col].iloc[start:end].tolist()
    sample_batch_results = ai_code_batch(sample_batch_texts)

    for r in sample_batch_results:
        sample_ai_concept1.append(r.get("concept1"))
        sample_ai_concept2.append(r.get("concept2"))

sample_df["ai_concept1"] = sample_ai_concept1
sample_df["ai_concept2"] = sample_ai_concept2

sample_df.to_csv("ai_coded_data.csv", index=False)
print("✅ Combined human + AI coded data saved to ai_coded_data.csv")
# Out:
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 1.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# ✅ Combined human + AI coded data saved to ai_coded_data.csv

# %%
sample_df = pd.read_csv("merged_coded_data.csv")

# %% [markdown]
# ## Evaluate your agreement
# Repeat the process until you reach at least 0.7 agreeability with the LLM

# %%
def krippendorff_alpha_for_concept(df, concept_name):
    data = [
        df[f"human_{concept_name}"].tolist(),
        df[f"ai_{concept_name}"].tolist()
    ]
    return krippendorff.alpha(reliability_data=data, level_of_measurement='nominal')

alpha_c1 = krippendorff_alpha_for_concept(sample_df, "concept1")
alpha_c2 = krippendorff_alpha_for_concept(sample_df, "concept2")

print("Krippendorff’s Alpha between Human and AI:")
print(f"• Concept 1: {alpha_c1:.3f}")
print(f"• Concept 2: {alpha_c2:.3f}")
# Out:
# Krippendorff’s Alpha between Human and AI:
# • Concept 1: 0.482
# • Concept 2: 0.398

# %% [markdown]
# ## Use your prompt to code the entire comments dataset

# %%
# !! Change file name !!
comments = pd.read_csv("@isitherightword_video_7569133665964297502_comments.csv")
comments = comments.head(1000)

ai_concept1, ai_concept2 = [], []

for start in range(0, len(comments), batch_size):
    print(f"Beginning coding round {(start/10) + 1}")
    end = start + batch_size
    batch_texts = comments[text_col].iloc[start:end].tolist()
    batch_results = ai_code_batch(batch_texts)

    for r in batch_results:
        ai_concept1.append(r.get("concept1"))
        ai_concept2.append(r.get("concept2"))

# Add results to dataframe
comments["ai_concept1"] = ai_concept1
comments["ai_concept2"] = ai_concept2

# Save to file
comments.to_csv("final_coded_data.csv", index=False)
print("✅ Finished Coding!")
# Out:
# Beginning coding round 1.0
# Beginning coding round 2.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 3.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 4.0
# Beginning coding round 5.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 6.0
# Beginning coding round 7.0
# Beginning coding round 8.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 9.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 10.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 11.0
# Beginning coding round 12.0
# Beginning coding round 13.0
# Beginning coding round 14.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 15.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 16.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 17.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 18.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 19.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 20.0
# Beginning coding round 21.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 22.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 23.0
# Beginning coding round 24.0
# Beginning coding round 25.0
# Beginning coding round 26.0
# Beginning coding round 27.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 28.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 29.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 30.0
# Beginning coding round 31.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 32.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 33.0
# Beginning coding round 34.0
# Beginning coding round 35.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 36.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 37.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 38.0
# Beginning coding round 39.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 40.0
# Beginning coding round 41.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 42.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 43.0
# Beginning coding round 44.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 45.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 46.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 47.0
# Beginning coding round 48.0
# Beginning coding round 49.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 50.0
# Beginning coding round 51.0
# Beginning coding round 52.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 53.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 54.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 55.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 56.0
# Beginning coding round 57.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 58.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 59.0
# Beginning coding round 60.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 61.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 62.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 63.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 64.0
# Beginning coding round 65.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 66.0
# Beginning coding round 67.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 68.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 69.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 70.0
# Beginning coding round 71.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 72.0
# Beginning coding round 73.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 74.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 75.0
# Beginning coding round 76.0
# Beginning coding round 77.0
# Beginning coding round 78.0
# Trying to parse
# ⚠️ Parsing error: name 'string' is not defined
# Beginning coding round 79.0
# Beginning coding round 80.0
# ✅ Finished Coding!

# %% [markdown]
# ## Analyze your data

# %%
final_coded_data = pd.read_csv("final_coded_data.csv")

# %% [markdown]
# #### Exploring quantity of comments

# %%
counts = {
    "ai_concept1": final_coded_data["ai_concept1"].sum(),
    "ai_concept2": final_coded_data["ai_concept2"].sum()
}

count_df = pd.DataFrame(list(counts.items()), columns=["Concept", "Total_1s"])

plt.figure(figsize=(6, 4))
plt.bar(count_df["Concept"], count_df["Total_1s"])
plt.title("Total Count of 1s by AI Concept")
plt.ylabel("Count of 1s")
plt.xlabel("Concept")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### What comments received more likes?

# %%
def collapse(x):
    if x.ai_concept1 == 1:
        return "concept1"
    elif x.ai_concept2 == 1:
        return "concept2"
    else:
        return "neither"

final_coded_data['collapsed_codes'] = final_coded_data.apply(collapse, axis=1)

# %%
sns.barplot(data=final_coded_data, y='collapsed_codes', x='digg_count')
# Out:
# <Axes: xlabel='digg_count', ylabel='collapsed_codes'>

# %% [markdown]
# #### What comments got the most replies?

# %%
sns.barplot(data=final_coded_data, y='collapsed_codes', x='reply_comment_total')
# Out:
# <Axes: xlabel='reply_comment_total', ylabel='collapsed_codes'>

# %% [markdown]
# #### What types of comments are shown more?
# This is a visibility metric: higher scores means higher visibility in the comment section

# %%
# Handle NaN values in sort_extra_score
def safe_literal_eval(x):
    try:
        return ast.literal_eval(x) if pd.notna(x) else None
    except:
        return None

final_coded_data['sort_extra_score_loaded'] = final_coded_data.sort_extra_score.apply(safe_literal_eval)
final_coded_data['show_more'] = final_coded_data.sort_extra_score_loaded.apply(
    lambda x: float(dict(x)['show_more_score']) if x is not None else None
)
sns.barplot(data=final_coded_data.dropna(subset='show_more'), y='collapsed_codes', x='show_more')
# Out:
# <Axes: xlabel='show_more', ylabel='collapsed_codes'>

# %% [markdown]
# #### Are there differences in age between commenters?

# %%
final_coded_data['users_loaded'] = final_coded_data.user.apply(lambda x: ast.literal_eval(x))
final_coded_data['age'] = final_coded_data.users_loaded.apply(
    lambda x: x['predicted_age_group'] if isinstance(x, dict) and 'predicted_age_group' in x else None
)

def reduce(x):
    try:
        return float(x)
    except:
        return float('nan')
final_coded_data['age'] = final_coded_data.age.apply(reduce)

# %%
sns.barplot(data=final_coded_data.dropna(subset='age'), y='collapsed_codes', x='age')
# Out:
# <Axes: xlabel='age', ylabel='collapsed_codes'>

# %% [markdown]
# - group -1 = 13-17
# - group 1 = 18-24
# - group 2 = 25-34
# - group 3 = 35-44
# - group 4 = 45-54
# - group 5 = 55+

# %% [markdown]
# #### Use an LLM to create one more visualization or analysis
# You might need to inspect your data!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your coded dataset
df = pd.read_csv("merged_coded_data.csv")

# Make sure the concept columns exist
if "ai_concept1" not in df.columns or "ai_concept2" not in df.columns:
    raise ValueError("Your dataset must include 'ai_concept1' and 'ai_concept2' columns.")

# Count how many comments fall into each category
concept_counts = {
    "Pro-Kayla / Anti-Taylor (Concept 1 = 1)": df["ai_concept1"].sum(),
    "Pro-Taylor / Anti-Kayla (Concept 2 = 1)": df["ai_concept2"].sum()
}

# Plot
plt.figure(figsize=(8,5))
plt.bar(concept_counts.keys(), concept_counts.values())
plt.ylabel("Number of Comments")
plt.title("Distribution of Coded TikTok Comments by Concept")
plt.xticks(rotation=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## What does it all mean??
# Spend 2-3 paragraphs reflecting on the results from your analysis. What are the implications of this work?
